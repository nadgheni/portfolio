# %% [markdown]
# <a href="https://colab.research.google.com/github/nadgheni/portfolio/blob/main/datapreprocessing_cong_cvs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-1fcc534e-fd15-4c5d-be58-f1a0afdd8995" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1fcc534e-fd15-4c5d-be58-f1a0afdd8995">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import sys
print(sys.version)
# Out:
# 3.9.16 (main, Dec  7 2022, 01:11:51)
# [GCC 9.4.0]

# %%
import pandas as pd

# Load your data into a Pandas DataFrame
df = pd.read_csv('Copy of cong_cvs_13042023.csv')

# Use the describe() method to summarize the main statistics of your data
df.describe()
# Out:
#                 id  ga_delivery      preterm  very_preterm  maternal_age  \
# count  3509.000000  3507.000000  3509.000000   3509.000000   3509.000000
# mean   1755.000000    38.690048     0.112283      0.016244     31.551724
# std    1013.105375     2.132657     0.315759      0.126430      6.074646
# min       1.000000    22.000000     0.000000      0.000000     18.000000
# 25%     878.000000    38.000000     0.000000      0.000000     27.000000
# 50%    1755.000000    39.000000     0.000000      0.000000     31.000000
# 75%    2632.000000    40.000000     0.000000      0.000000     36.000000
# max    3509.000000    56.000000     1.000000      1.000000     52.000000
#
#        gravida_mrm_n  parity_mrm_n  interpreg_interval  preexsit_hypertension  \
# count    3509.000000   3509.000000         2651.000000            3509.000000
# mean        4.015674      2.441151         1014.686911               0.019664
# ...

# %%
df.describe(include='all')
# Out:
#                  id           Project_ID  ga_delivery anc_intitation_q1  \
# count   3509.000000                 3509  3507.000000               663
# unique          NaN                 3509          NaN                 2
# top             NaN  CVSCONG-00193-35090          NaN              Late
# freq            NaN                    1          NaN               461
# mean    1755.000000                  NaN    38.690048               NaN
# std     1013.105375                  NaN     2.132657               NaN
# min        1.000000                  NaN    22.000000               NaN
# 25%      878.000000                  NaN    38.000000               NaN
# 50%     1755.000000                  NaN    39.000000               NaN
# 75%     2632.000000                  NaN    40.000000               NaN
# max     3509.000000                  NaN    56.000000               NaN
#
#        previous_child_lbw_q1 previous_child_premature_q1  \
# ...

# %%
means = df.mean()
# Out:
# <ipython-input-36-da899156809a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = df.mean()

# %%
means.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.info()
df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3509 entries, 0 to 3508
# Data columns (total 75 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3509 non-null   int64
#  1   Project_ID                        3509 non-null   object
#  2   ga_delivery                       3507 non-null   float64
#  3   anc_intitation_q1                 663 non-null    object
#  4   previous_child_lbw_q1             2589 non-null   object
#  5   previous_child_premature_q1       2567 non-null   object
#  6   previous_child_miscarriage_q1     2600 non-null   object
#  7   previous_child_stillbirth_q1      2528 non-null   object
#  8   planned_pregnancy_q1              3267 non-null   object
#  9   infertility_treatment_q1          3228 non-null   object
#  10  period_regular_q1                 3282 non-null   object
# ...

# %%
# !pip install missingpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Load your data into a Pandas DataFrame and replace any missing values with np.nan or None values:

# %%
import pandas as pd
import numpy as np

# Load your data into a Pandas DataFrame
df = pd.read_csv('Copy of cong_cvs_13042023.csv')

# Replace missing values with NaN or None
df.replace(['', '?', 'NA', 'N/A', 'Unknown'], np.nan, inplace=True)

# %%
# !pip install scikit-learn==0.22
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 21.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-learn: filename=scikit_learn-0.22-cp39-cp39-linux_x86_64.whl size=23561012 sha256=9063d23afa0decc30d1e37205033623e3d81a26407778d988af8da4626f27f6d
#   Stored in directory: /root/.cache/pip/wheels/e7/12/1e/86d5527d8864a27433c021141ad54bfd87775982ea961f9c60
# Successfully built scikit-learn
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install -U scikit-learn

# %%
# !pip install missingpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Import the MissForest class from the missingpy library:

# %%
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %%
from missingpy import MissForest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-013fce00c795> in <cell line: 1>()
# ----> 1 from missingpy import MissForest
#
# /usr/local/lib/python3.9/dist-packages/missingpy/__init__.py in <module>
# ----> 1 from .knnimpute import KNNImputer
#       2 from .missforest import MissForest
#       3
#       4 __all__ = ['KNNImputer', 'MissForest']
#
# /usr/local/lib/python3.9/dist-packages/missingpy/knnimpute.py in <module>
#      11 from sklearn.utils.validation import check_is_fitted
#      12 from sklearn.utils.validation import FLOAT_DTYPES
# ---> 13 from sklearn.neighbors.base import _check_weights
#      14 from sklearn.neighbors.base import _get_weights
#      15
#
# ImportError: cannot import name '_check_weights' from 'sklearn.neighbors._base' (/usr/local/lib/python3.9/dist-packages/sklearn/neighbors/_base.py)
#
# ...

# %%
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/epsilon-machine/missingpy.git to /tmp/pip-req-build-o_f7ncjr
#   Running command git clone --filter=blob:none --quiet https://github.com/epsilon-machine/missingpy.git /tmp/pip-req-build-o_f7ncjr
#   Resolved https://github.com/epsilon-machine/missingpy.git to commit 49fb1f61647e5399d1164a63b44e2fbfbc4ed8ad
#   Preparing metadata (setup.py) ... done
